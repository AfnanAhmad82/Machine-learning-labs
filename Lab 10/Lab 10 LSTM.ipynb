# %%
import os
os.chdir(r'D:\University Data\8 semester\Lab Machine learning')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from timeseires.utils.to_split import to_split
from timeseires.utils.multivariate_multi_step import multivariate_multi_step
from timeseires.utils.multivariate_single_step import multivariate_single_step
from timeseires.utils.univariate_multi_step import univariate_multi_step
from timeseires.utils.univariate_single_step import univariate_single_step
from timeseires.utils.CosineAnnealingLRS import CosineAnnealingLRS
from timeseires.callbacks.EpochCheckpoint import EpochCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from timeseires.callbacks.TrainingMonitor import TrainingMonitor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import LSTM, Bidirectional, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D,TimeDistributed
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,MaxPooling1D,Concatenate,AveragePooling1D, GlobalMaxPooling1D, Input
from tensorflow.keras.models import Sequential,Model
import pandas as pd
import time, pickle
import numpy as np
import tensorflow.keras.backend as K
import tensorflow
from tensorflow.keras.layers import Input, Reshape, Lambda
from tensorflow.keras.layers import Layer, Flatten, LeakyReLU, concatenate, Dense
from tensorflow.keras.regularizers import l2
import glob
import h5py
import matplotlib.pyplot as plt
from keras.callbacks import Callback

# %%
#lookback = 24
model = None
start_epoch = 0
time_steps=24
num_features=21

# %%
def create_lstm():
    input_data = Input(shape=(time_steps, num_features))
    lstm_layer1 = LSTM(8, return_sequences=True)(input_data)
    lstm_layer2 = LSTM(20)(lstm_layer1)
    x = Flatten()(lstm_layer2)
    output_data = Dense(1)(x)
    model = Model(input_data, output_data)
    return model

# %%
model1 = create_lstm()
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 21)]          0
#
#  lstm (LSTM)                 (None, 24, 8)             960
#
#  lstm_1 (LSTM)               (None, 20)                2320
#
#  flatten (Flatten)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 3,301
# Trainable params: 3,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tensorflow.keras.utils.plot_model(model1 )

# %%
checkpoints = r'D:\University Data\8 semester\Lab Machine learning\lab10\\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
OUTPUT_PATH = r'D:\University Data\8 semester\Lab Machine learning\lab10'
FIG_PATH = os.path.sep.join([OUTPUT_PATH,"\history.png"])
JSON_PATH = os.path.sep.join([OUTPUT_PATH,"\history.json"])

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]

# %%
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model =create_lstm()
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] compiling model...

# %%
import os
path_dataset =r'D:\University Data\8 semester\Lab Machine learning'
path_tr = os.path.join(path_dataset, 'AEP_train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'AEP_validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'AEP_test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'AEP_Scaler.pkl')
scaler         = pickle.load(open(path_scaler, 'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# C:\Users\AFNAN AHMAD\anaconda3\envs\myenv\lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ((84907, 21), (24259, 21), (12130, 21))

# %%
time_steps=24
num_features=21

# %%
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=1)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=1)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=1)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.5867531299591064 sec

# %%
epochs = 60
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,verbose = verbose)
# Out:
# Epoch 1/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0411 - mae: 0.0411 - mape: 719.2260
# Epoch 1: val_loss improved from inf to 0.02106, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0001-loss0.02.h5
# 2653/2653 [==============================] - 100s 36ms/step - loss: 0.0410 - mae: 0.0410 - mape: 719.0750 - val_loss: 0.0211 - val_mae: 0.0211 - val_mape: 10.1398
# Epoch 2/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0169 - mae: 0.0169 - mape: 343.3965
# Epoch 2: val_loss improved from 0.02106 to 0.01491, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0002-loss0.01.h5
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0169 - mae: 0.0169 - mape: 343.3965 - val_loss: 0.0149 - val_mae: 0.0149 - val_mape: 7.2020
# Epoch 3/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0122 - mae: 0.0122 - mape: 226.0056
# Epoch 3: val_loss improved from 0.01491 to 0.01052, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0003-loss0.01.h5
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0122 - mae: 0.0122 - mape: 225.9584 - val_loss: 0.0105 - val_mae: 0.0105 - val_mape: 4.7257
# Epoch 4/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0102 - mae: 0.0102 - mape: 246.7937
# Epoch 4: val_loss improved from 0.01052 to 0.00966, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0004-loss0.01.h5
# 2653/2653 [==============================] - 119s 45ms/step - loss: 0.0102 - mae: 0.0102 - mape: 246.7937 - val_loss: 0.0097 - val_mae: 0.0097 - val_mape: 4.1093
# Epoch 5/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0091 - mae: 0.0091 - mape: 270.2976
# Epoch 5: val_loss did not improve from 0.00966
# 2653/2653 [==============================] - 117s 44ms/step - loss: 0.0091 - mae: 0.0091 - mape: 270.2976 - val_loss: 0.0098 - val_mae: 0.0098 - val_mape: 4.3489
# Epoch 6/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0085 - mape: 146.9198
# Epoch 6: val_loss improved from 0.00966 to 0.00734, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0006-loss0.01.h5
# 2653/2653 [==============================] - 115s 44ms/step - loss: 0.0085 - mae: 0.0085 - mape: 146.8892 - val_loss: 0.0073 - val_mae: 0.0073 - val_mape: 3.1780
# Epoch 7/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0082 - mae: 0.0082 - mape: 238.6933
# Epoch 7: val_loss did not improve from 0.00734
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0082 - mae: 0.0082 - mape: 238.6432 - val_loss: 0.0083 - val_mae: 0.0083 - val_mape: 3.7613
# Epoch 8/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0080 - mape: 175.2278
# Epoch 8: val_loss improved from 0.00734 to 0.00703, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0008-loss0.01.h5
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0080 - mae: 0.0080 - mape: 175.1910 - val_loss: 0.0070 - val_mae: 0.0070 - val_mape: 2.9329
# Epoch 9/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 26.1099
# Epoch 10: val_loss did not improve from 0.00703
# 2653/2653 [==============================] - 2596s 979ms/step - loss: 0.0077 - mae: 0.0077 - mape: 26.1099 - val_loss: 0.0071 - val_mae: 0.0071 - val_mape: 3.0647
# Epoch 11/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0075 - mae: 0.0075 - mape: 150.0906
# Epoch 11: val_loss did not improve from 0.00703
# 2653/2653 [==============================] - 113s 43ms/step - loss: 0.0075 - mae: 0.0075 - mape: 150.0906 - val_loss: 0.0080 - val_mae: 0.0080 - val_mape: 3.4019
# Epoch 12/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0074 - mape: 124.8672
# Epoch 12: val_loss improved from 0.00703 to 0.00665, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0012-loss0.01.h5
# 2653/2653 [==============================] - 123s 47ms/step - loss: 0.0074 - mae: 0.0074 - mape: 124.8412 - val_loss: 0.0067 - val_mae: 0.0067 - val_mape: 3.0571
# Epoch 13/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0073 - mape: 93.2528
# Epoch 13: val_loss did not improve from 0.00665
# 2653/2653 [==============================] - 126s 48ms/step - loss: 0.0073 - mae: 0.0073 - mape: 93.2337 - val_loss: 0.0079 - val_mae: 0.0079 - val_mape: 3.3023
# Epoch 14/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0073 - mape: 75.0795
# Epoch 14: val_loss did not improve from 0.00665
# 2653/2653 [==============================] - 113s 42ms/step - loss: 0.0073 - mae: 0.0073 - mape: 75.0641 - val_loss: 0.0068 - val_mae: 0.0068 - val_mape: 2.9136
# Epoch 15/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0072 - mae: 0.0072 - mape: 154.7690
# Epoch 15: val_loss improved from 0.00665 to 0.00658, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0015-loss0.01.h5
# 2653/2653 [==============================] - 113s 43ms/step - loss: 0.0072 - mae: 0.0072 - mape: 154.7690 - val_loss: 0.0066 - val_mae: 0.0066 - val_mape: 2.8521
# Epoch 16/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0071 - mae: 0.0071 - mape: 48.9329
# Epoch 16: val_loss did not improve from 0.00658
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0071 - mae: 0.0071 - mape: 48.9329 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 2.9870
# Epoch 17/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0071 - mae: 0.0071 - mape: 28.7648
# Epoch 17: val_loss did not improve from 0.00658
# 2653/2653 [==============================] - 109s 41ms/step - loss: 0.0071 - mae: 0.0071 - mape: 28.7591 - val_loss: 0.0074 - val_mae: 0.0074 - val_mape: 3.1735
# Epoch 18/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0071 - mae: 0.0071 - mape: 18.2123
# Epoch 18: val_loss did not improve from 0.00658
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0071 - mae: 0.0071 - mape: 18.2123 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 3.5619
# Epoch 19/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0070 - mae: 0.0070 - mape: 35.8886
# Epoch 19: val_loss did not improve from 0.00658
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0070 - mae: 0.0070 - mape: 35.8886 - val_loss: 0.0068 - val_mae: 0.0068 - val_mape: 2.8720
# Epoch 20/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0070 - mae: 0.0070 - mape: 8.9687
# Epoch 20: val_loss improved from 0.00658 to 0.00649, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0020-loss0.01.h5
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0070 - mae: 0.0070 - mape: 8.9672 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.8297
# Epoch 21/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0069 - mae: 0.0069 - mape: 80.9330
# Epoch 21: val_loss did not improve from 0.00649
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0069 - mae: 0.0069 - mape: 80.9330 - val_loss: 0.0077 - val_mae: 0.0077 - val_mape: 3.4021
# Epoch 22/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0068 - mape: 16.7032
# Epoch 22: val_loss did not improve from 0.00649
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0068 - mae: 0.0068 - mape: 16.7001 - val_loss: 0.0070 - val_mae: 0.0070 - val_mape: 2.9256
# Epoch 23/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0068 - mape: 29.8232
# Epoch 23: val_loss improved from 0.00649 to 0.00625, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0023-loss0.01.h5
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0068 - mae: 0.0068 - mape: 29.8172 - val_loss: 0.0062 - val_mae: 0.0062 - val_mape: 2.6207
# Epoch 24/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0068 - mae: 0.0068 - mape: 22.6945
# Epoch 24: val_loss did not improve from 0.00625
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0068 - mae: 0.0068 - mape: 22.6945 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 3.4297
# Epoch 25/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0068 - mae: 0.0068 - mape: 56.5920
# Epoch 25: val_loss did not improve from 0.00625
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0068 - mae: 0.0068 - mape: 56.5920 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 3.0818
# Epoch 26/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0067 - mae: 0.0067 - mape: 13.3414
# Epoch 26: val_loss did not improve from 0.00625
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0067 - mae: 0.0067 - mape: 13.3414 - val_loss: 0.0064 - val_mae: 0.0064 - val_mape: 2.7477
# Epoch 27/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 92.0767
# Epoch 27: val_loss did not improve from 0.00625
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0066 - mae: 0.0066 - mape: 92.0576 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 2.9146
# Epoch 28/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 103.6325
# Epoch 28: val_loss did not improve from 0.00625
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0066 - mae: 0.0066 - mape: 103.6325 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.9072
# Epoch 29/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 27.1804
# Epoch 29: val_loss improved from 0.00625 to 0.00610, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0029-loss0.01.h5
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0066 - mae: 0.0066 - mape: 27.1804 - val_loss: 0.0061 - val_mae: 0.0061 - val_mape: 2.5893
# Epoch 30/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 44.1132
# Epoch 30: val_loss did not improve from 0.00610
# 2653/2653 [==============================] - 111s 42ms/step - loss: 0.0066 - mae: 0.0066 - mape: 44.1042 - val_loss: 0.0075 - val_mae: 0.0075 - val_mape: 3.2524
# Epoch 31/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 44.6121
# Epoch 31: val_loss improved from 0.00610 to 0.00591, saving model to D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0031-loss0.01.h5
# 2653/2653 [==============================] - 110s 41ms/step - loss: 0.0066 - mae: 0.0066 - mape: 44.6121 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.4800
# Epoch 32/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0066 - mape: 63.4418
# Epoch 32: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 110s 42ms/step - loss: 0.0066 - mae: 0.0066 - mape: 63.4418 - val_loss: 0.0067 - val_mae: 0.0067 - val_mape: 3.1334
# Epoch 33/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0065 - mape: 66.5419
# Epoch 33: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0065 - mae: 0.0065 - mape: 66.5280 - val_loss: 0.0066 - val_mae: 0.0066 - val_mape: 2.7230
# Epoch 34/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0065 - mae: 0.0065 - mape: 106.2805
# Epoch 34: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0065 - mae: 0.0065 - mape: 106.2805 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 2.6990
# Epoch 35/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 34.6990
# Epoch 35: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 34.6990 - val_loss: 0.0061 - val_mae: 0.0061 - val_mape: 2.6690
# Epoch 36/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 38.6768
# Epoch 36: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 38.6692 - val_loss: 0.0078 - val_mae: 0.0078 - val_mape: 3.1979
# Epoch 37/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0065 - mape: 11.8075
# Epoch 37: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 113s 42ms/step - loss: 0.0065 - mae: 0.0065 - mape: 11.8054 - val_loss: 0.0061 - val_mae: 0.0061 - val_mape: 2.6862
# Epoch 38/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 116.1196
# Epoch 38: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 113s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 116.1196 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.7979
# Epoch 39/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 124.6865
# Epoch 39: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 124.6607 - val_loss: 0.0067 - val_mae: 0.0067 - val_mape: 2.8244
# Epoch 40/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 59.1617
# Epoch 40: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 59.1617 - val_loss: 0.0066 - val_mae: 0.0066 - val_mape: 2.9312
# Epoch 41/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 56.7159
# Epoch 41: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 112s 42ms/step - loss: 0.0064 - mae: 0.0064 - mape: 56.7044 - val_loss: 0.0060 - val_mae: 0.0060 - val_mape: 2.5753
# Epoch 42/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 70.5844
# Epoch 42: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 70.5844 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 2.6958
# Epoch 43/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 58.7265
# Epoch 43: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 114s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 58.7145 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.8102
# Epoch 44/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 47.7639
# Epoch 44: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 47.7541 - val_loss: 0.0068 - val_mae: 0.0068 - val_mape: 2.9547
# Epoch 45/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 49.4080
# Epoch 45: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 49.3979 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 2.8158
# Epoch 46/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 88.4672
# Epoch 46: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 116s 44ms/step - loss: 0.0063 - mae: 0.0063 - mape: 88.4672 - val_loss: 0.0060 - val_mae: 0.0060 - val_mape: 2.5218
# Epoch 47/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 135.7148
# Epoch 47: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 135.7148 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 2.7969
# Epoch 48/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 105.7029
# Epoch 48: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0062 - mae: 0.0062 - mape: 105.6809 - val_loss: 0.0068 - val_mae: 0.0068 - val_mape: 2.8590
# Epoch 49/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 135.2050
# Epoch 49: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 116s 44ms/step - loss: 0.0063 - mae: 0.0063 - mape: 135.1767 - val_loss: 0.0060 - val_mae: 0.0060 - val_mape: 2.6136
# Epoch 50/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 33.7054
# Epoch 50: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 115s 43ms/step - loss: 0.0063 - mae: 0.0063 - mape: 33.6986 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.8076
# Epoch 51/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 130.6611
# Epoch 51: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 114s 43ms/step - loss: 0.0062 - mae: 0.0062 - mape: 130.6611 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 2.7571
# Epoch 52/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 54.4462
# Epoch 52: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 114s 43ms/step - loss: 0.0062 - mae: 0.0062 - mape: 54.4462 - val_loss: 0.0066 - val_mae: 0.0066 - val_mape: 2.7844
# Epoch 53/60
# 2651/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 104.8662
# Epoch 53: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 66s 25ms/step - loss: 0.0062 - mae: 0.0062 - mape: 104.8056 - val_loss: 0.0061 - val_mae: 0.0061 - val_mape: 2.5210
# Epoch 54/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 4.5219
# Epoch 54: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 66s 25ms/step - loss: 0.0062 - mae: 0.0062 - mape: 4.5219 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 2.8491
# Epoch 55/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 166.9464
# Epoch 55: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 68s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 166.9114 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 2.6974
# Epoch 56/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 43.4420
# Epoch 56: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 69s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 43.4420 - val_loss: 0.0067 - val_mae: 0.0067 - val_mape: 2.7951
# Epoch 57/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 93.9311
# Epoch 57: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 70s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 93.9311 - val_loss: 0.0060 - val_mae: 0.0060 - val_mape: 2.5369
# Epoch 58/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 112.2762
# Epoch 58: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 68s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 112.2529 - val_loss: 0.0061 - val_mae: 0.0061 - val_mape: 2.6958
# Epoch 59/60
# 2651/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 58.7972
# Epoch 59: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 68s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 58.7636 - val_loss: 0.0062 - val_mae: 0.0062 - val_mape: 2.7174
# Epoch 60/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0062 - mape: 74.3687
# Epoch 60: val_loss did not improve from 0.00591
# 2653/2653 [==============================] - 68s 26ms/step - loss: 0.0062 - mae: 0.0062 - mape: 74.3538 - val_loss: 0.0079 - val_mae: 0.0079 - val_mape: 3.5234

# %%
model = load_model(r'D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0031-loss0.01.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 379/379 [==============================] - 3s 3ms/step
# Mean Absolute Error (MAE): 95.52
# Median Absolute Error (MedAE): 75.09
# Mean Squared Error (MSE): 16432.34
# Root Mean Squared Error (RMSE): 128.19
# Mean Absolute Percentage Error (MAPE): 0.65 %
# Median Absolute Percentage Error (MDAPE): 0.52 %
#
#
# y_test_unscaled.shape=  (12105, 1)
# y_pred.shape=  (12105, 1)

# %%
checkpoints = r'D:\University Data\8 semester\Lab Machine learning\lab10\E2-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
model=r'D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0031-loss0.01.h5'
start_epoch= 34

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model = PC.build(time_steps=24, num_features=21, reg=0.0005)
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] loading D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0031-loss0.01.h5...
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 9.999999747378752e-05

# %%
epochs = 10
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                        verbose = verbose)
# Out:
# Epoch 1/10
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 52.3666
# Epoch 3: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 63s 24ms/step - loss: 0.0057 - mae: 0.0057 - mape: 52.3559 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.4865
# Epoch 4/10
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 38.4672
# Epoch 4: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 58s 22ms/step - loss: 0.0057 - mae: 0.0057 - mape: 38.4595 - val_loss: 0.0058 - val_mae: 0.0058 - val_mape: 2.4673
# Epoch 5/10
# 2651/2653 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 26.0479
# Epoch 5: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 57s 22ms/step - loss: 0.0057 - mae: 0.0057 - mape: 26.0335 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.4640
# Epoch 6/10
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 47.1517
# Epoch 6: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 59s 22ms/step - loss: 0.0057 - mae: 0.0057 - mape: 47.1517 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.5263
# Epoch 7/10
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 50.6022
# Epoch 7: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 59s 22ms/step - loss: 0.0057 - mae: 0.0057 - mape: 50.5919 - val_loss: 0.0058 - val_mae: 0.0058 - val_mape: 2.4575
# Epoch 8/10
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 64.1301
# Epoch 8: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 60s 23ms/step - loss: 0.0057 - mae: 0.0057 - mape: 64.1301 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.4437
# Epoch 9/10
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 73.8885
# Epoch 9: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 61s 23ms/step - loss: 0.0057 - mae: 0.0057 - mape: 73.8885 - val_loss: 0.0059 - val_mae: 0.0059 - val_mape: 2.5043
# Epoch 10/10
# 2651/2653 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0057 - mape: 93.1348
# Epoch 10: val_loss did not improve from 0.00581
# 2653/2653 [==============================] - 61s 23ms/step - loss: 0.0057 - mae: 0.0057 - mape: 93.0810 - val_loss: 0.0060 - val_mae: 0.0060 - val_mape: 2.4903

# %%
model = load_model(r'D:\University Data\8 semester\Lab Machine learning\lab10\E1-cp-0031-loss0.01.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 379/379 [==============================] - 2s 4ms/step
# Mean Absolute Error (MAE): 95.52
# Median Absolute Error (MedAE): 75.09
# Mean Squared Error (MSE): 16432.34
# Root Mean Squared Error (RMSE): 128.19
# Mean Absolute Percentage Error (MAPE): 0.65 %
# Median Absolute Percentage Error (MDAPE): 0.52 %
#
#
# y_test_unscaled.shape=  (12105, 1)
# y_pred.shape=  (12105, 1)
